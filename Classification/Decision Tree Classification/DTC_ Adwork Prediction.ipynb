# %% [markdown]
# # Step 1: Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2: Loading data set

# %%
ads_df = pd.read_csv('Social_Network_Ads.csv')

# %% [markdown]
# # Step 3: Exploratory Data Analysis

# %%
ads_df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
ads_df.tail()
# Out:
#      Age  EstimatedSalary  Purchased
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1

# %%
ads_df.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
ads_df.shape
# Out:
# (400, 3)

# %%
sns.heatmap(ads_df.isnull() , yticklabels = False , cbar = False , cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Step 4: Model Training

# %%
x = ads_df.iloc[: , 0:2].values
x
# Out:
# array([[    19,  19000],
#        [    35,  20000],
#        [    26,  43000],
#        [    27,  57000],
#        [    19,  76000],
#        [    27,  58000],
#        [    27,  84000],
#        [    32, 150000],
#        [    25,  33000],
#        [    35,  65000],
#        [    26,  80000],
#        [    26,  52000],
#        [    20,  86000],
#        [    32,  18000],
#        [    18,  82000],
#        [    29,  80000],
#        [    47,  25000],
#        [    45,  26000],
#        [    46,  28000],
#        [    48,  29000],
#        [    45,  22000],
#        [    47,  49000],
#        [    48,  41000],
#        [    45,  22000],
#        [    46,  23000],
#        [    47,  20000],
#        [    49,  28000],
#        [    47,  30000],
#        [    29,  43000],
#        [    31,  18000],
#        [    31,  74000],
#        [    27, 137000],
#        [    21,  16000],
#        [    28,  44000],
#        [    27,  90000],
#        [    35,  27000],
#        [    33,  28000],
# ...

# %%
y = ads_df.iloc[: , :1].values

# %%
y
# Out:
# array([[19],
#        [35],
#        [26],
#        [27],
#        [19],
#        [27],
#        [27],
#        [32],
#        [25],
#        [35],
#        [26],
#        [26],
#        [20],
#        [32],
#        [18],
#        [29],
#        [47],
#        [45],
#        [46],
#        [48],
#        [45],
#        [47],
#        [48],
#        [45],
#        [46],
#        [47],
#        [49],
#        [47],
#        [29],
#        [31],
#        [31],
#        [27],
#        [21],
#        [28],
#        [27],
#        [35],
#        [33],
#        [30],
#        [26],
#        [27],
#        [27],
#        [33],
#        [35],
#        [30],
#        [28],
#        [23],
#        [25],
#        [27],
#        [30],
#        [31],
#        [24],
#        [18],
#        [29],
#        [35],
#        [27],
#        [24],
#        [23],
#        [28],
#        [22],
#        [32],
#        [27],
#        [25],
#        [23],
#        [32],
#        [59],
#        [24],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 0)

# %%
x_train.shape
# Out:
# (320, 2)

# %%
x_test.shape
# Out:
# (80, 2)

# %%
from sklearn.tree import DecisionTreeClassifier

dtClassifier = DecisionTreeClassifier(criterion = 'entropy' , random_state = 0)
dtClassifier.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
gg = dtClassifier.predict([['20' , '36000']])

gg
# Out:
# array([20], dtype=int64)
